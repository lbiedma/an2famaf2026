# %% [markdown]
# ![ejercicio2p5.png](attachment:ejercicio2p5.png)

# %% [markdown]
# Sea $A = U\Sigma V^T$ la descomposición svd de $A$, $\varepsilon > 0$ y $p = min\{m,n\}$

# %% [markdown]
# $
# \Sigma =
# \begin{bmatrix}
# \Sigma_{r} & 0^T \\
# 0 & 0 \\
# \end{bmatrix}
# $
# con
# $\Sigma_{r} =
# \begin{bmatrix}
# \sigma_1 &          &   &         \\
#          & \sigma_2 &   &         \\
#          &         &\ddots&       \\
#          &         &    & \sigma_r
# \end{bmatrix}$

# %% [markdown]
# A partir de la descomposición svd de $A$ se construye la matriz $A$:

# %% [markdown]
# $$A_{\varepsilon} = U\Sigma_{\varepsilon} V^T$$

# %% [markdown]
# con
# $\Sigma_{\varepsilon} =
# \begin{bmatrix}
# \sigma_1 &          &   &          &\\
#          & \sigma_2 &   &          &\\
#          &         &\ddots&        &\\
#          &         &    & \sigma_r & \\
#          &         &    &          &  \varepsilon /2 \\
#          &         &    &          &   & \ddots \\
#          &         &    &          &   &     & \varepsilon /2 \\
# \end{bmatrix}$

# %% [markdown]
# $||A -A_{\varepsilon}||_2 = ||U\Sigma V^T - U\Sigma_{\varepsilon} V^T||_2 = ||U(\Sigma - \Sigma_{\varepsilon})V^T||_2 = ||\Sigma - \Sigma_{\varepsilon}||_2$

# %% [markdown]
# $=\left\lVert\begin{bmatrix}
# \sigma_1 &          &   &          &\\
#          & \sigma_2 &   &          &\\
#          &         &\ddots&        &\\
#          &         &    & \sigma_r & \\
#          &         &    &          &  0 \\
#          &         &    &          &   & \ddots \\
#          &         &    &          &   &     & 0 \\
# \end{bmatrix}-\begin{bmatrix}
# \sigma_1 &          &   &          &\\
#          & \sigma_2 &   &          &\\
#          &         &\ddots&        &\\
#          &         &    & \sigma_r & \\
#          &         &    &          &  \varepsilon /2 \\
#          &         &    &          &   & \ddots \\
#          &         &    &          &   &     & \varepsilon /2 \\
# \end{bmatrix}
# \right\rVert_2 =$

# %% [markdown]
# $=\left\lVert
# \begin{bmatrix}
#  &          &   &          &\\
#          & 0 &   &          &\\
#          &         &\ddots&        &\\
#          &         &    & 0 & \\
#          &         &    &          &  -\varepsilon /2 \\
#          &         &    &          &   & \ddots \\
#          &         &    &          &   &     & -\varepsilon /2 \\
# \end{bmatrix}
# \right\rVert_2 = \varepsilon / 2 < \varepsilon$
