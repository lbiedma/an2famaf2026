# %% [markdown]
# <img src = 'data:image/png;base64,...' width = 800>

# %% [markdown]
# $$
# \begin{bmatrix}
#  a_{11} & a_{12} & 0 & 0...0& a_{n1}\\
#  a_{21} & a_{22} & a_{23} &0...0 & 0\\
#   0 & 0...0 \ddots & \ddots&  \ddots & \vdots \\
#   0 & 0...0 & \ddots&  \ddots &  a_{n-1,n}\\
#  a_{n1} & 0...0 &  & a_{n,n-1} & a_{nn}
# \end{bmatrix}
# $$

# %% [markdown]
# Primero aplicamos operaciones elementales a los elementos no nulos de la columna 1

# %% [markdown]
# para $k = 1$ los únicos elementos que sé deben aplicar operaciones elementales son $a_{21}$ y $a_{n1}$. Pero hay que tener en cuenta que se actuializan las filas 2 y $n$ también, por lo que para la primera iteración proponemos lo siguiente:

# %% [markdown]
# para $i = 2$:
# $$
# a_{21}^{(1)} = a_{21} - \dfrac{a_{21}}{a_{11}}a_{11} = 0
# $$
#
# $$
# a_{22}^{(1)} = a_{22} - \dfrac{a_{21}}{a_{11}}a_{12}
# $$
#
# $$
# a_{23}^{(1)} = a_{23} - \dfrac{a_{21}}{a_{11}}0 = a_{23}
# $$
#
# $$
# a_{2n}^{(1)} = 0 - \dfrac{a_{21}}{a_{11}}a_{1n} = -\dfrac{a_{21}}{a_{11}}a_{1n}
# $$

# %% [markdown]
# Note que la actualización de $a_{n2}^{(1)}$ pasa a ser un elemento no nulo y esto hará que se repitá en la siguiente iteración. También, note que la actaulización de $a_{23}^{(1)}$ se mantiene igual, por lo que lo descartamos. Esto se puede hacer de forma recursiva para el resto de las columnas. Proponemos el siguiente algoritmo:

# %% [markdown]
# Sean $A\in \R^{n\times n}$ definido por la estrutura del ejercicio 7:
#
# $\hspace{0.5cm}$ para $k= 1, ..., n-1$:
#
# $\hspace{1cm}$ para $i = k+1, n$
# $\hspace{1.5cm}$ para $j = i-1, i, n$
#
# $$
# a_{ij} =a_{ij}  - \dfrac{a_{i,i-1}}{a_{i-1,i-1}}a_{i-1, j}
# $$
#
# $\hat{A} = A$
#
# Retornar $A$
